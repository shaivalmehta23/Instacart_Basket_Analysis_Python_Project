# %% [markdown]
# # 01 Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
path = r'C:\Users\shaiv\Downloads\Instacart Basket Analysis'
path
# Out:
# 'C:\\Users\\shaiv\\Downloads\\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_products_new_variable_derived.pkl'))

# %% [markdown]
# # 02 Aggregate mean of the order_number for entire dataframe

# %%
ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # 03 The mean values for the department ids present in the subset have all changed because some have increased while others have decreased.

# %% [markdown]
# # 04 Loyalty flag column was created in Part 1 of this exercise.

# %% [markdown]
# # 05 Using the loyalty flag column created and checking the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).

# %%
# Aggregating data based on prices and getting statistics such as mean, min, max, std and median

ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'std', 'median']})
# Out:
#                     prices
#                       mean  min   max       std median
# loyalty_flag
# Loyal customer    7.773487  1.0  25.0  4.205886    7.4
# New customer      7.801077  1.0  25.0  4.266452    7.4
# Regular customer  7.798145  1.0  25.0  4.254540    7.4

# %% [markdown]
# ##### Looking at the stats it looks like the prices of products purchased by loyal customers is almost same as product purchased by regular or new customers. The mean and standard deviation of prices are almost same.

# %% [markdown]
# # 06 Creating a spending flag for each user based on the average price across all their orders

# %%
# Create new column for avergae price of the order

ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# ...

# %%
# Criteria for each amount spent

ords_prods_merge.loc[ords_prods_merge['average_spend'] < 10, 'spender_flag'] = 'Low_spender'
ords_prods_merge.loc[ords_prods_merge['average_spend'] >= 10, 'spender_flag'] = 'High_spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     32285150
# High_spender      119709
# Name: count, dtype: int64

# %% [markdown]
# ##### There are more less spender (average < 10) than high spender (average >= 10).

# %% [markdown]
# # 07 Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column.

# %%
# Create new column for median in the days_since_prior_order

ords_prods_merge['customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# ...

# %%
# Criteria for frequency flags

ords_prods_merge.loc[ords_prods_merge['customer_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['customer_frequency'] > 10) & (ords_prods_merge['customer_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %% [markdown]
# ##### Almost 2/3 rd of the customers are frequent customer who will be be receiving the notifications.

# %%
ords_prods_merge[['user_id', 'customer_frequency', 'frequency_flag']].head(60)
# Out:
#     user_id  customer_frequency         frequency_flag
# 0         1                20.5  Non-frequent customer
# 1         1                20.5  Non-frequent customer
# 2         1                20.5  Non-frequent customer
# 3         1                20.5  Non-frequent customer
# 4         1                20.5  Non-frequent customer
# 5         1                20.5  Non-frequent customer
# 6         1                20.5  Non-frequent customer
# 7         1                20.5  Non-frequent customer
# 8         1                20.5  Non-frequent customer
# 9         1                20.5  Non-frequent customer
# 10        1                20.5  Non-frequent customer
# 11        1                20.5  Non-frequent customer
# 12        1                20.5  Non-frequent customer
# 13        1                20.5  Non-frequent customer
# 14        1                20.5  Non-frequent customer
# 15        1                20.5  Non-frequent customer
# ...

# %% [markdown]
# # 09 Export dataframe

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_new_variables.pkl'))
